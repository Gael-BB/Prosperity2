# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../prices/submission1_round_3.csv', header=0, sep=';')
data.head(20)
# Out:
#     day  timestamp       product  bid_price_1  bid_volume_1  bid_price_2  \
# 0     2          0         ROSES        14421            30      14420.0
# 1     2          0  STRAWBERRIES         4036           181          NaN
# 2     2          0     AMETHYSTS         9996             2       9995.0
# 3     2          0       ORCHIDS         1053             7       1052.0
# 4     2          0     STARFRUIT         5023             1       5022.0
# 5     2          0     CHOCOLATE         7888           117          NaN
# 6     2          0   GIFT_BASKET        70593             2      70592.0
# 7     2        100     CHOCOLATE         7889           137          NaN
# 8     2        100   GIFT_BASKET        70610             2      70609.0
# 9     2        100     AMETHYSTS         9996             2       9995.0
# 10    2        100  STRAWBERRIES         4036           189          NaN
# 11    2        100         ROSES        14423            57          NaN
# 12    2        100     STARFRUIT         5027            11       5023.0
# 13    2        100       ORCHIDS         1051             8       1050.0
# 14    2        200     AMETHYSTS         9995            20          NaN
# 15    2        200       ORCHIDS         1051             7       1050.0
# 16    2        200     STARFRUIT         5021            20          NaN
# 17    2        200     CHOCOLATE         7890            43       7889.0
# 18    2        200   GIFT_BASKET        70611            14      70609.0
# 19    2        200  STRAWBERRIES         4036           228          NaN
#
#     bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           42.0          NaN           NaN        14422            72
# 1            NaN          NaN           NaN         4037           181
# 2           25.0          NaN           NaN        10004             2
# 3            2.0       1046.0          46.0         1059             7
# 4           27.0          NaN           NaN         5029            27
# 5            NaN          NaN           NaN         7890           117
# 6           14.0      70591.0          30.0        70604             2
# 7            NaN          NaN           NaN         7890            50
# 8           10.0      70608.0          20.0        70621             2
# 9           28.0          NaN           NaN         9998             1
# 10           NaN          NaN           NaN         4037            87
# 11           NaN          NaN           NaN        14425            57
# 12           3.0       5022.0          30.0         5029            30
# 13           2.0       1045.0          46.0         1058             8
# 14           NaN          NaN           NaN        10005            20
# 15           4.0       1045.0          41.0         1058             7
# 16           NaN          NaN           NaN         5028            20
# 17          75.0          NaN           NaN         7891           118
# 18          25.0          NaN           NaN        70624            14
# 19           NaN          NaN           NaN         4038           228
#
#     ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 0           NaN           NaN          NaN           NaN    14421.5
# 1           NaN           NaN          NaN           NaN     4036.5
# 2       10005.0          25.0          NaN           NaN    10000.0
# 3        1060.0           2.0       1067.0          46.0     1056.0
# 4           NaN           NaN          NaN           NaN     5026.0
# 5           NaN           NaN          NaN           NaN     7889.0
# 6       70605.0          14.0      70606.0          30.0    70598.5
# 7        7891.0          87.0          NaN           NaN     7889.5
# 8       70622.0          10.0      70623.0          20.0    70615.5
# 9       10004.0           2.0      10005.0          28.0     9997.0
# 10       4038.0         102.0          NaN           NaN     4036.5
# 11          NaN           NaN          NaN           NaN    14424.0
# 12          NaN           NaN          NaN           NaN     5028.0
# 13       1059.0           2.0       1065.0          46.0     1054.5
# 14          NaN           NaN          NaN           NaN    10000.0
# 15       1059.0           4.0       1065.0          41.0     1054.5
# 16          NaN           NaN          NaN           NaN     5024.5
# 17          NaN           NaN          NaN           NaN     7890.5
# 18      70625.0          25.0          NaN           NaN    70617.5
# 19          NaN           NaN          NaN           NaN     4037.0
#
#     profit_and_loss
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# 5          0.000000
# 6          0.000000
# 7          0.000000
# 8          0.000000
# 9          0.000000
# 10         0.000000
# 11         0.000000
# 12         0.000000
# 13         0.000000
# 14         2.000000
# 15         0.000000
# 16        22.398438
# 17         0.000000
# 18         0.000000
# 19         0.000000

# %%
products = ['AMETHYSTS', 'STARFRUIT', 'ORCHIDS', 'CHOCOLATE', 'STRAWBERRIES', 'ROSES', 'GIFT_BASKET']
prices = {}
profits = {}
for product in products:
    prices[product] = data[data['product'] == product]['mid_price'].values
    profits[product] = data[data['product'] == product]['profit_and_loss'].values

# %%
for product in products:
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(prices[product], label='price', color='red')
    ax2.plot(profits[product], label='profit', color='blue')
    ax1.set_ylabel('Price')
    ax2.set_ylabel('Profit')
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')
    plt.title(product)
    plt.show()
