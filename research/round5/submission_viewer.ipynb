# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('submission3_round_5.csv', header=0, sep=';')
data.head(10)
# Out:
#    day  timestamp         product  bid_price_1  bid_volume_1  bid_price_2  \
# 0    4          0       STARFRUIT         4906             2       4905.0
# 1    4          0    STRAWBERRIES         3957           199          NaN
# 2    4          0         COCONUT         9883           133       9882.0
# 3    4          0  COCONUT_COUPON          574            45          NaN
# 4    4          0           ROSES        13712            63          NaN
# 5    4          0         ORCHIDS         1099             6       1097.0
# 6    4          0     GIFT_BASKET        69141             2      69140.0
# 7    4          0       CHOCOLATE         7832           129          NaN
# 8    4          0       AMETHYSTS         9998             3       9996.0
# 9    4        100         COCONUT         9885           109       9884.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0          20.0          NaN           NaN         4912            22
# ...

# %%
products = ['AMETHYSTS', 'STARFRUIT', 'ORCHIDS', 'CHOCOLATE', 'STRAWBERRIES', 'ROSES', 'GIFT_BASKET', 'COCONUT', 'COCONUT_COUPON']
prices = {}
profits = {}
for product in products:
    prices[product] = data[data['product'] == product]['mid_price'].values
    profits[product] = data[data['product'] == product]['profit_and_loss'].values

# %%
for product in products:
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(prices[product], label='price', color='red')
    ax2.plot(profits[product], label='profit', color='blue')
    ax1.set_ylabel('Price')
    ax2.set_ylabel('Profit')
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')
    plt.title(product)
    plt.show()

# %%
sum_basket_profit = profits['GIFT_BASKET'] + profits['CHOCOLATE'] + profits['STRAWBERRIES'] + profits['ROSES']
print(f"Sum of basket and ingredients profit: {sum_basket_profit[-1]}.")

plt.plot(sum_basket_profit, label='Sum of basket and ingredients profit', color='blue')
plt.plot(profits['GIFT_BASKET'], label='Gift basket profit', color='red')
plt.legend(loc='lower left')
plt.show()
# Out:
# Sum of basket and ingredients profit: -4825.5.
