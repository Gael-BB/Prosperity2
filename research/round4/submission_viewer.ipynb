# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('results_round_4.csv', header=0, sep=';')
data.head(10)
# Out:
#    day  timestamp         product  bid_price_1  bid_volume_1  bid_price_2  \
# 0    4          0       STARFRUIT         4906             3       4905.0
# 1    4          0    STRAWBERRIES         3957           272          NaN
# 2    4          0         COCONUT         9883           136       9882.0
# 3    4          0  COCONUT_COUPON          574            38          NaN
# 4    4          0           ROSES        13712            53          NaN
# 5    4          0         ORCHIDS         1099             8       1097.0
# 6    4          0     GIFT_BASKET        69141             2      69140.0
# 7    4          0       CHOCOLATE         7832           136          NaN
# 8    4          0       AMETHYSTS         9996             2       9995.0
# 9    4        100         COCONUT         9885           101       9884.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0          26.0          NaN           NaN         4912            28
# 1           NaN          NaN           NaN         3959           272
# 2          49.0          NaN           NaN         9884           136
# 3           NaN          NaN           NaN          575            38
# 4           NaN          NaN           NaN        13714            53
# 5           5.0       1090.0          49.0         1107             8
# 6          15.0      69139.0          21.0        69152             2
# 7           NaN          NaN           NaN         7833            41
# 8          26.0          NaN           NaN        10004             2
# 9          42.0          NaN           NaN         9886           101
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 0          NaN           NaN          NaN           NaN     4909.0
# 1          NaN           NaN          NaN           NaN     3958.0
# 2       9885.0          49.0          NaN           NaN     9883.5
# 3          NaN           NaN          NaN           NaN      574.5
# 4          NaN           NaN          NaN           NaN    13713.0
# 5       1108.0           5.0       1116.0          49.0     1103.0
# 6      69153.0          15.0      69154.0          21.0    69146.5
# 7       7834.0          95.0          NaN           NaN     7832.5
# 8      10005.0          26.0          NaN           NaN    10000.0
# 9       9887.0          42.0          NaN           NaN     9885.5
#
#    profit_and_loss
# 0           0.0000
# 1           0.0000
# 2           0.0000
# 3           0.0000
# 4           0.0000
# 5           0.0000
# 6           0.0000
# 7           0.0000
# 8           0.0000
# 9        -140.4375

# %%
products = ['AMETHYSTS', 'STARFRUIT', 'ORCHIDS', 'CHOCOLATE', 'STRAWBERRIES', 'ROSES', 'GIFT_BASKET', 'COCONUT', 'COCONUT_COUPON']
prices = {}
profits = {}
for product in products:
    prices[product] = data[data['product'] == product]['mid_price'].values
    profits[product] = data[data['product'] == product]['profit_and_loss'].values

# %%
for product in products:
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(prices[product], label='price', color='red')
    ax2.plot(profits[product], label='profit', color='blue')
    ax1.set_ylabel('Price')
    ax2.set_ylabel('Profit')
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')
    plt.title(product)
    plt.show()
